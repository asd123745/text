# %%
import matplotlib.pyplot as pl

# %%
x=[1,2,6,7]
y=[1,3,7,5]
#matplotlib qt
pl.plot(x,y 'r--', marker ='0')
# Out:
#   File "<ipython-input-23-63929d878185>", line 4
#     pl.plot(x,y 'r--', marker ='0')
#                     ^
# SyntaxError: invalid syntax

# %%
import numpy as np

# %%
a=np.arange(-10,10,0.1)
a
# Out:
# array([-1.00000000e+01, -9.90000000e+00, -9.80000000e+00, -9.70000000e+00,
#        -9.60000000e+00, -9.50000000e+00, -9.40000000e+00, -9.30000000e+00,
#        -9.20000000e+00, -9.10000000e+00, -9.00000000e+00, -8.90000000e+00,
#        -8.80000000e+00, -8.70000000e+00, -8.60000000e+00, -8.50000000e+00,
#        -8.40000000e+00, -8.30000000e+00, -8.20000000e+00, -8.10000000e+00,
#        -8.00000000e+00, -7.90000000e+00, -7.80000000e+00, -7.70000000e+00,
#        -7.60000000e+00, -7.50000000e+00, -7.40000000e+00, -7.30000000e+00,
#        -7.20000000e+00, -7.10000000e+00, -7.00000000e+00, -6.90000000e+00,
#        -6.80000000e+00, -6.70000000e+00, -6.60000000e+00, -6.50000000e+00,
#        -6.40000000e+00, -6.30000000e+00, -6.20000000e+00, -6.10000000e+00,
#        -6.00000000e+00, -5.90000000e+00, -5.80000000e+00, -5.70000000e+00,
#        -5.60000000e+00, -5.50000000e+00, -5.40000000e+00, -5.30000000e+00,
# ...

# %%
b=a*a
b
# Out:
# array([1.00000000e+02, 9.80100000e+01, 9.60400000e+01, 9.40900000e+01,
#        9.21600000e+01, 9.02500000e+01, 8.83600000e+01, 8.64900000e+01,
#        8.46400000e+01, 8.28100000e+01, 8.10000000e+01, 7.92100000e+01,
#        7.74400000e+01, 7.56900000e+01, 7.39600000e+01, 7.22500000e+01,
#        7.05600000e+01, 6.88900000e+01, 6.72400000e+01, 6.56100000e+01,
#        6.40000000e+01, 6.24100000e+01, 6.08400000e+01, 5.92900000e+01,
#        5.77600000e+01, 5.62500000e+01, 5.47600000e+01, 5.32900000e+01,
#        5.18400000e+01, 5.04100000e+01, 4.90000000e+01, 4.76100000e+01,
#        4.62400000e+01, 4.48900000e+01, 4.35600000e+01, 4.22500000e+01,
#        4.09600000e+01, 3.96900000e+01, 3.84400000e+01, 3.72100000e+01,
#        3.60000000e+01, 3.48100000e+01, 3.36400000e+01, 3.24900000e+01,
#        3.13600000e+01, 3.02500000e+01, 2.91600000e+01, 2.80900000e+01,
#        2.70400000e+01, 2.60100000e+01, 2.50000000e+01, 2.40100000e+01,
# ...

# %%
pl.plot(a,b ,'r--')

# %%
b2=10*a
pl.figure(1)
pl.plot(a,b ,'r--')
pl.figure(2)
pl.plot(a,b2 ,'g--')

# %%
b2=10*a
pl.subplot(1,2,1)
pl.plot(a,b ,'r--')
pl.subplot(1,2,2)
pl.plot(a,b2 ,'g--')

# %%
b2=10*a
# %matplotlib qt
pl.subplot(1,2,1)
pl.plot(a,b ,'r--')
pl.subplot(1,2,2)
pl.plot(a,b2 ,'g--')

# %%
x=np.arange(0,5,1)
y1=np.sin(t)
y2=np.cos(t)
pl.plot(t,y1)
pl.plot(t,y2,'r--',marker =  ' * ')
pl.grid()
pl.xlabel('Time')
pl.ylabel('Amp')
pl.title('SinCos')
pl.legend(['Sin','Cos'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     308             try:
# --> 309                 Path(marker)
#     310                 self._marker_function = self._set_vertices
#
# ~\Anaconda3\lib\site-packages\matplotlib\path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     126         """
# --> 127         vertices = _to_unmasked_float_array(vertices)
#     128         if vertices.ndim != 2 or vertices.shape[1] != 2:
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1389     else:
# -> 1390         return np.asarray(x, float)
#    1391
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#
# ...

# %% [markdown]
# - [문제] subplot 을 이용해서 2행 1열 구조 2개씩
# - 4가지 marker,스타일,색상 다르개
# - 범례 표시
# - x,y,제목
#
# x= 0,5,1
# y1= x+1
# y2 = x+2
# y3= x+3
# y4 = x+4

# %%
t=np.arange(0,5,1)
y1=np.sin(t)
y2=np.cos(t)
pl.plot(t,y1)
pl.plot(t,y2,'r--')
pl.xlabel('Time')
pl.ylabel('Amp')
pl.title('SinCos')
pl.legend(['Sin','Cos'])
